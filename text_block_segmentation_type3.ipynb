# %%
# !pip install importlib-metadata==3.2.0
# !python -m spacy download en_core_web_sm
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz!pip install PyPDF2
# !pip install PyPDF2
# !pip install pdfminer.six
# !pip install PyMuPDF
# !pip install tika
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting importlib-metadata==3.2.0
#   Downloading importlib_metadata-3.2.0-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata==3.2.0) (3.15.0)
# Installing collected packages: importlib-metadata
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.1.0
#     Uninstalling importlib-metadata-6.1.0:
#       Successfully uninstalled importlib-metadata-6.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.4.3 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 3.2.0 which is incompatible.
# gym 0.25.2 requires importlib-metadata>=4.8.0; python_version < "3.10", but you have importlib-metadata 3.2.0 which is incompatible.
# flask 2.2.3 requires importlib-metadata>=3.6.0; python_version < "3.10", but you have importlib-metadata 3.2.0 which is incompatible.
# Successfully installed importlib-metadata-3.2.0
# 2023-04-06 13:30:13.305504: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-06 13:30:14.510358: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 63.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.9/dist-packages (from en-core-web-sm==3.5.0) (3.5.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.22.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (67.6.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.27.1)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz!pip
#   ERROR: HTTP error 404 while getting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz!pip
# ERROR: Could not install requirement https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz!pip because of HTTP error 404 Client Error: Not Found for url: https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz!pip for URL https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz!pip
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 KB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /usr/local/lib/python3.9/dist-packages (from PyPDF2) (4.5.0)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pdfminer.six
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 42.0 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.9/dist-packages (from pdfminer.six) (40.0.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from pdfminer.six) (2.0.12)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=36.0.0->pdfminer.six) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.21)
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20221105
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.21.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 44.4 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.21.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tika
#   Downloading tika-2.6.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tika) (67.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from tika) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->tika) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->tika) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->tika) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->tika) (1.26.15)
# Building wheels for collected packages: tika
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32641 sha256=88e5da49fe8e5092571114eec72a43d156a9e8a7fd5751105319346b98697037
#   Stored in directory: /root/.cache/pip/wheels/13/56/18/e752060632d32c39c9c4545e756dad281f8504dafcfac02b95
# Successfully built tika
# Installing collected packages: tika
# Successfully installed tika-2.6.0

# %%
import PyPDF2
import nltk
import os
import re
import string
import spacy
import json
from tika import parser
import fitz
from operator import itemgetter
from bs4 import BeautifulSoup

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
nltk.download('wordnet')
nltk.download('brown')
nltk.download('maxent_ne_chunker')
nltk.download('words')


from pdfminer.high_level import extract_text
from spacy.matcher import Matcher
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
# !rm -r '/content/extracted_data'
# !rm -r '/content/text_resumes'
# !rm -r '/content/json_data'
# !rm -r '/content/headings'
# Out:
# rm: cannot remove '/content/extracted_data': No such file or directory
# rm: cannot remove '/content/text_resumes': No such file or directory
# rm: cannot remove '/content/json_data': No such file or directory
# rm: cannot remove '/content/headings': No such file or directory

# %%
# !mkdir '/content/text_resumes'
# !mkdir '/content/extracted_data'
# !mkdir '/content/json_data'
# !mkdir '/content/headings'

# %%
class ResumeInformationExtractor:
  def __init__(self, directory_path):
    self.directory = directory_path
    self.text_directory = '/content/text_resumes'
    self.block_directory = '/content/extracted_data'
    self.json_directory = '/content/json_data'
    self.headings_directory = '/content/headings'
    self.store_text()
    print("DONE")

  def fonts(self, doc, granularity=False):
    styles = {}
    font_counts = {}
    for page in doc:
      blocks = page.get_text("dict")["blocks"]
      for b in blocks:
          if b['type'] == 0:
              for l in b["lines"]:
                  for s in l["spans"]:
                      if granularity:
                          identifier = "{0}_{1}_{2}_{3}".format(s['size'], s['flags'], s['font'], s['color'])
                          styles[identifier] = {'size': s['size'], 'flags': s['flags'], 'font': s['font'],
                                                'color': s['color']}
                      else:
                          identifier = "{0}".format(s['size'])
                          styles[identifier] = {'size': s['size'], 'font': s['font']}

                      font_counts[identifier] = font_counts.get(identifier, 0) + 1  # count the fonts usage

    font_counts = sorted(font_counts.items(), key=itemgetter(1), reverse=True)

    if len(font_counts) < 1:
        raise ValueError("Zero discriminating fonts found!")

    return font_counts, styles

  def font_tags(self, font_counts, styles):
    p_style = styles[font_counts[0][0]]
    p_size = p_style['size']
    font_sizes = []
    for (font_size, count) in font_counts:
        font_sizes.append(float(font_size))
    font_sizes.sort(reverse=True)
    idx = 0
    size_tag = {}
    for size in font_sizes:
        idx += 1
        if size == p_size:
            idx = 0
            size_tag[size] = '<p>'
        if size > p_size:
            size_tag[size] = '<h{0}>'.format(idx)
        elif size < p_size:
            size_tag[size] = '<s{0}>'.format(idx)

    return size_tag


  def headers_para(self, doc, size_tag):
    header_para = []
    first = True
    previous_s = {}

    for page in doc:
        blocks = page.get_text("dict")["blocks"]
        for b in blocks:
            if b['type'] == 0:
                block_string = ""
                for l in b["lines"]:
                    for s in l["spans"]:
                        if s['text'].strip():
                            if first:
                                previous_s = s
                                first = False
                                block_string = size_tag[s['size']] + s['text']
                            else:
                                if s['size'] == previous_s['size']:
                                    if block_string and all((c == "|") for c in block_string):
                                        block_string = size_tag[s['size']] + s['text']
                                    if block_string == "":
                                        block_string = size_tag[s['size']] + s['text']
                                    else:
                                        block_string += " " + s['text']
                                else:
                                    header_para.append(block_string)
                                    block_string = size_tag[s['size']] + s['text']
                                previous_s = s
                    block_string += "|"
                header_para.append(block_string)
    result = '\n'.join(header_para)
    return header_para , result



  def get_headings(self, elements):
    headings_ = []
    for item in elements:
        if item.startswith(('<h1>', '<h2>')):
            headings_.append(item)
    headings = []
    for item in headings_:
        if '>' in item and len(item.split('>')) > 1:
            text = item.split('>')[1].split('|')[0].strip()
            headings.append(text)
    filtered_words = []
    for word in headings:
      word = ''.join(e for e in word if e.isalnum() or e in ['/', '\\', ' '])
      filtered_words.append(word)
    return filtered_words



  def extract_data(self, text , headings):
    regex_patterns = {}
    for heading in headings:
        regex_patterns[heading] = re.compile(r'^' + heading, re.IGNORECASE)

    text_blocks = {}
    for heading in headings:
        text_blocks[heading] = ''

    current_heading = None
    i = 0

    for line in text.split('\n'):
        found_heading = False
        for heading, regex_pattern in regex_patterns.items():
            if regex_pattern.match(line):
                current_heading = heading
                found_heading = True
                break
        if found_heading:
            continue

        if current_heading is not None:
            text_blocks[current_heading] += line + '\n'
    return text_blocks

  def get_file_content(self, doc):
    header_para = []
    first = True
    previous_s = {}

    for page in doc:
        blocks = page.get_text("dict")["blocks"]
        for b in blocks:
            if b['type'] == 0:
                block_string = ""
                for l in b["lines"]:
                    for s in l["spans"]:
                        if s['text'].strip():
                            if first:
                                previous_s = s
                                first = False
                                block_string = s['text']
                            else:
                                if s['size'] == previous_s['size']:
                                    if block_string and all((c == "|") for c in block_string):
                                        block_string = s['text']
                                    if block_string == "":
                                        block_string = s['text']
                                    else:
                                        block_string += " " + s['text']
                                else:
                                    header_para.append(block_string)
                                    block_string = s['text']
                                previous_s = s
                header_para.append(block_string)
    result = '\n'.join(header_para)
    return result

  def store_text(self):
    print(self.directory)
    files = sorted(os.listdir(self.directory))

    for file in files:
        path = self.directory + '/' + file
        doc = fitz.open(path)
        text_data = self.get_file_content(doc)
        if not text_data:
          continue


        font_counts, styles = self.fonts(doc, granularity=False)
        size_tag = self.font_tags(font_counts, styles)
        elements , res = self.headers_para(doc, size_tag)
        headings = self.get_headings(elements)
        with open(self.headings_directory + '/' + file.split('.')[0] + '.txt', 'w') as f:
          f.write(str(headings))
        with open(self.text_directory + '/' + file.split('.')[0] + '.txt', 'w') as f:
            f.write(res)

        text_blocks = self.extract_data(text_data , headings)
        with open(self.block_directory + '/' + file.split('.')[0] + '.txt', 'w') as f:
            for heading, text_block in text_blocks.items():
                if text_block:
                    f.write(heading.upper() + '\n')
                    f.write(text_block + '-' * 50 + '\n')

        with open(self.json_directory + '/' + file.split('.')[0] + '.json', 'w') as f:
            non_empty_text_blocks = {key: value.replace('\n', ' ') for key, value in text_blocks.items() if value}
            json.dump(non_empty_text_blocks, f, indent=2)
    return

# %%
RESUME_DIRECTORY = '/content/type3'
ResumeInformationExtractor(RESUME_DIRECTORY)
# !zip -r /content/json_data3.zip /content/json_data
# Out:
# /content/type3
# DONE
# updating: content/json_data/ (stored 0%)
# updating: content/json_data/pdf_resume_220.json (deflated 32%)
# updating: content/json_data/pdf_resume_306.json (deflated 45%)
# updating: content/json_data/pdf_resume_967.json (deflated 45%)
# updating: content/json_data/pdf_resume_419.json (deflated 41%)
# updating: content/json_data/pdf_resume_938.json (deflated 45%)
# updating: content/json_data/pdf_resume_179.json (deflated 46%)
# updating: content/json_data/pdf_resume_38.json (stored 0%)
# updating: content/json_data/pdf_resume_490.json (deflated 45%)
# updating: content/json_data/pdf_resume_426.json (deflated 49%)
# updating: content/json_data/pdf_resume_833.json (deflated 44%)
# updating: content/json_data/pdf_resume_572.json (deflated 43%)
# updating: content/json_data/pdf_resume_80.json (deflated 47%)
# updating: content/json_data/pdf_resume_122.json (deflated 37%)
# updating: content/json_data/pdf_resume_879.json (deflated 62%)
# updating: content/json_data/pdf_resume_886.json (deflated 46%)
# updating: content/json_data/pdf_resume_642.json (deflated 50%)
# updating: content/json_data/pdf_resume_156.json (deflated 49%)
# updating: content/json_data/pdf_resume_172.json (deflated 33%)
# updating: content/json_data/pdf_resume_37.json (stored 0%)
# updating: content/json_data/pdf_resume_104.json (deflated 44%)
# updating: content/json_data/pdf_resume_729.json (deflated 43%)
# updating: content/json_data/pdf_resume_622.json (stored 0%)
# updating: content/json_data/pdf_resume_826.json (deflated 43%)
# updating: content/json_data/pdf_resume_338.json (deflated 45%)
# updating: content/json_data/pdf_resume_518.json (deflated 44%)
# updating: content/json_data/pdf_resume_227.json (deflated 53%)
# updating: content/json_data/pdf_resume_316.json (stored 0%)
# updating: content/json_data/pdf_resume_497.json (deflated 48%)
# updating: content/json_data/pdf_resume_322.json (deflated 39%)
# updating: content/json_data/pdf_resume_981.json (deflated 43%)
# updating: content/json_data/pdf_resume_376.json (deflated 52%)
# updating: content/json_data/pdf_resume_28.json (stored 0%)
# updating: content/json_data/pdf_resume_262.json (deflated 38%)
# updating: content/json_data/pdf_resume_413.json (deflated 50%)
# updating: content/json_data/pdf_resume_298.json (deflated 47%)
# updating: content/json_data/pdf_resume_597.json (deflated 42%)
# updating: content/json_data/pdf_resume_56.json (deflated 44%)
# updating: content/json_data/pdf_resume_620.json (deflated 47%)
# updating: content/json_data/pdf_resume_197.json (deflated 49%)
# updating: content/json_data/pdf_resume_553.json (deflated 44%)
# updating: content/json_data/pdf_resume_911.json (deflated 50%)
# updating: content/json_data/pdf_resume_776.json (deflated 46%)
# updating: content/json_data/pdf_resume_577.json (deflated 40%)
# updating: content/json_data/pdf_resume_915.json (deflated 47%)
# updating: content/json_data/pdf_resume_645.json (deflated 41%)
# updating: content/json_data/pdf_resume_107.json (deflated 44%)
# updating: content/json_data/pdf_resume_955.json (deflated 43%)
# updating: content/json_data/pdf_resume_724.json (deflated 40%)
# updating: content/json_data/pdf_resume_169.json (deflated 51%)
# updating: content/json_data/pdf_resume_369.json (deflated 38%)
# updating: content/json_data/pdf_resume_180.json (deflated 46%)
# updating: content/json_data/pdf_resume_684.json (stored 0%)
# updating: content/json_data/pdf_resume_1023.json (stored 0%)
# updating: content/json_data/pdf_resume_627.json (deflated 43%)
# updating: content/json_data/pdf_resume_606.json (deflated 45%)
# updating: content/json_data/pdf_resume_678.json (deflated 41%)
# updating: content/json_data/pdf_resume_949.json (deflated 50%)
# updating: content/json_data/pdf_resume_942.json (deflated 50%)
# updating: content/json_data/pdf_resume_472.json (deflated 49%)
# updating: content/json_data/pdf_resume_562.json (deflated 47%)
# updating: content/json_data/pdf_resume_595.json (stored 0%)
# updating: content/json_data/pdf_resume_877.json (deflated 48%)
# updating: content/json_data/pdf_resume_213.json (stored 0%)
# updating: content/json_data/pdf_resume_521.json (deflated 48%)
# updating: content/json_data/pdf_resume_310.json (deflated 47%)
# updating: content/json_data/pdf_resume_200.json (deflated 35%)
# updating: content/json_data/pdf_resume_932.json (stored 0%)
# updating: content/json_data/pdf_resume_15.json (deflated 33%)
# updating: content/json_data/pdf_resume_175.json (deflated 39%)
# updating: content/json_data/pdf_resume_442.json (deflated 45%)
# updating: content/json_data/pdf_resume_129.json (deflated 36%)
# updating: content/json_data/pdf_resume_105.json (deflated 48%)
# updating: content/json_data/pdf_resume_101.json (stored 0%)
# updating: content/json_data/pdf_resume_728.json (deflated 49%)
# updating: content/json_data/pdf_resume_722.json (deflated 42%)
# updating: content/json_data/pdf_resume_986.json (deflated 47%)
# updating: content/json_data/pdf_resume_531.json (deflated 48%)
# updating: content/json_data/pdf_resume_397.json (deflated 50%)
# updating: content/json_data/pdf_resume_204.json (deflated 36%)
# updating: content/json_data/pdf_resume_987.json (deflated 54%)
# updating: content/json_data/pdf_resume_363.json (deflated 44%)
# updating: content/json_data/pdf_resume_733.json (deflated 44%)
# updating: content/json_data/pdf_resume_799.json (deflated 47%)
# updating: content/json_data/pdf_resume_230.json (deflated 39%)
# updating: content/json_data/pdf_resume_803.json (deflated 45%)
# updating: content/json_data/pdf_resume_541.json (stored 0%)
# updating: content/json_data/pdf_resume_616.json (deflated 43%)
# updating: content/json_data/pdf_resume_695.json (stored 0%)
# updating: content/json_data/pdf_resume_207.json (deflated 49%)
# updating: content/json_data/pdf_resume_215.json (deflated 49%)
# updating: content/json_data/pdf_resume_916.json (deflated 39%)
# updating: content/json_data/pdf_resume_927.json (deflated 50%)
# updating: content/json_data/pdf_resume_183.json (stored 0%)
# updating: content/json_data/pdf_resume_328.json (deflated 44%)
# updating: content/json_data/pdf_resume_717.json (deflated 42%)
# updating: content/json_data/pdf_resume_778.json (stored 0%)
# updating: content/json_data/pdf_resume_389.json (deflated 40%)
# updating: content/json_data/pdf_resume_192.json (deflated 51%)
# updating: content/json_data/pdf_resume_340.json (deflated 51%)
# updating: content/json_data/pdf_resume_621.json (deflated 48%)
# updating: content/json_data/pdf_resume_1025.json (deflated 45%)
# updating: content/json_data/pdf_resume_231.json (deflated 42%)
# updating: content/json_data/pdf_resume_958.json (stored 0%)
# updating: content/json_data/pdf_resume_240.json (deflated 37%)
# updating: content/json_data/pdf_resume_123.json (deflated 37%)
# updating: content/json_data/pdf_resume_52.json (deflated 44%)
# updating: content/json_data/pdf_resume_294.json (deflated 49%)
# updating: content/json_data/pdf_resume_675.json (deflated 42%)
# updating: content/json_data/pdf_resume_864.json (deflated 52%)
# updating: content/json_data/pdf_resume_341.json (deflated 41%)
# updating: content/json_data/pdf_resume_751.json (deflated 40%)
# updating: content/json_data/pdf_resume_570.json (deflated 40%)
# updating: content/json_data/pdf_resume_427.json (deflated 49%)
# updating: content/json_data/pdf_resume_514.json (deflated 43%)
# updating: content/json_data/pdf_resume_189.json (deflated 49%)
# updating: content/json_data/pdf_resume_956.json (deflated 47%)
# updating: content/json_data/pdf_resume_492.json (deflated 34%)
# updating: content/json_data/pdf_resume_257.json (deflated 37%)
# updating: content/json_data/pdf_resume_548.json (deflated 44%)
# updating: content/json_data/pdf_resume_546.json (deflated 45%)
# updating: content/json_data/pdf_resume_353.json (deflated 41%)
# updating: content/json_data/pdf_resume_870.json (deflated 41%)
# updating: content/json_data/pdf_resume_365.json (deflated 50%)
# updating: content/json_data/pdf_resume_901.json (deflated 49%)
# updating: content/json_data/pdf_resume_447.json (deflated 52%)
# updating: content/json_data/pdf_resume_356.json (deflated 47%)
# updating: content/json_data/pdf_resume_800.json (stored 0%)
# updating: content/json_data/pdf_resume_814.json (stored 0%)
# updating: content/json_data/pdf_resume_871.json (deflated 52%)
# updating: content/json_data/pdf_resume_936.json (stored 0%)
# updating: content/json_data/pdf_resume_236.json (deflated 49%)
# updating: content/json_data/pdf_resume_159.json (deflated 43%)
# updating: content/json_data/pdf_resume_205.json (deflated 49%)
# updating: content/json_data/pdf_resume_1030.json (deflated 38%)
# updating: content/json_data/pdf_resume_464.json (stored 0%)
# updating: content/json_data/pdf_resume_1017.json (deflated 45%)
# updating: content/json_data/pdf_resume_1003.json (deflated 54%)
# updating: content/json_data/pdf_resume_114.json (deflated 48%)
# updating: content/json_data/pdf_resume_3.json (stored 0%)
# updating: content/json_data/pdf_resume_244.json (stored 0%)
# updating: content/json_data/pdf_resume_973.json (deflated 49%)
# updating: content/json_data/pdf_resume_191.json (deflated 44%)
# updating: content/json_data/pdf_resume_528.json (stored 0%)
# updating: content/json_data/pdf_resume_656.json (deflated 39%)
# updating: content/json_data/pdf_resume_798.json (stored 0%)
# updating: content/json_data/pdf_resume_27.json (stored 0%)
# updating: content/json_data/pdf_resume_1020.json (deflated 47%)
# updating: content/json_data/pdf_resume_511.json (deflated 59%)
# updating: content/json_data/pdf_resume_451.json (deflated 37%)
# updating: content/json_data/pdf_resume_795.json (deflated 42%)
# updating: content/json_data/pdf_resume_206.json (deflated 46%)
# updating: content/json_data/pdf_resume_115.json (deflated 27%)
# updating: content/json_data/pdf_resume_946.json (deflated 54%)
# updating: content/json_data/pdf_resume_853.json (deflated 38%)
# updating: content/json_data/pdf_resume_434.json (deflated 53%)
# updating: content/json_data/pdf_resume_633.json (deflated 34%)
# updating: content/json_data/pdf_resume_694.json (deflated 44%)
# updating: content/json_data/pdf_resume_608.json (deflated 47%)
# updating: content/json_data/pdf_resume_771.json (deflated 48%)
# updating: content/json_data/pdf_resume_539.json (deflated 28%)
# updating: content/json_data/pdf_resume_368.json (deflated 45%)
# updating: content/json_data/pdf_resume_287.json (deflated 49%)
# updating: content/json_data/pdf_resume_502.json (deflated 50%)
# updating: content/json_data/pdf_resume_60.json (deflated 47%)
# updating: content/json_data/pdf_resume_646.json (deflated 45%)
# updating: content/json_data/pdf_resume_602.json (stored 0%)
# updating: content/json_data/pdf_resume_416.json (deflated 46%)
# updating: content/json_data/pdf_resume_817.json (deflated 40%)
# updating: content/json_data/pdf_resume_284.json (deflated 46%)
# updating: content/json_data/pdf_resume_315.json (deflated 50%)
# updating: content/json_data/pdf_resume_210.json (deflated 48%)
# updating: content/json_data/pdf_resume_819.json (deflated 50%)
# updating: content/json_data/pdf_resume_218.json (deflated 46%)
# updating: content/json_data/pdf_resume_781.json (stored 0%)
# updating: content/json_data/pdf_resume_487.json (deflated 54%)
# updating: content/json_data/pdf_resume_758.json (deflated 40%)
# updating: content/json_data/pdf_resume_988.json (deflated 40%)
# updating: content/json_data/pdf_resume_960.json (deflated 46%)
# updating: content/json_data/pdf_resume_288.json (deflated 41%)
# updating: content/json_data/pdf_resume_791.json (deflated 51%)
# updating: content/json_data/pdf_resume_245.json (deflated 39%)
# updating: content/json_data/pdf_resume_65.json (deflated 42%)
# updating: content/json_data/pdf_resume_74.json (stored 0%)
# updating: content/json_data/pdf_resume_431.json (deflated 43%)
# updating: content/json_data/pdf_resume_556.json (deflated 41%)
# updating: content/json_data/pdf_resume_270.json (stored 0%)
# updating: content/json_data/pdf_resume_346.json (deflated 45%)
# updating: content/json_data/pdf_resume_496.json (deflated 42%)
# updating: content/json_data/pdf_resume_276.json (deflated 46%)
# updating: content/json_data/pdf_resume_58.json (deflated 53%)
# updating: content/json_data/pdf_resume_4.json (deflated 39%)
# updating: content/json_data/pdf_resume_573.json (stored 0%)
# updating: content/json_data/pdf_resume_794.json (deflated 45%)
# updating: content/json_data/pdf_resume_137.json (deflated 46%)
# updating: content/json_data/pdf_resume_61.json (deflated 52%)
# updating: content/json_data/pdf_resume_714.json (deflated 48%)
# updating: content/json_data/pdf_resume_358.json (deflated 34%)
# updating: content/json_data/pdf_resume_247.json (deflated 38%)
# updating: content/json_data/pdf_resume_821.json (deflated 54%)
# updating: content/json_data/pdf_resume_251.json (deflated 39%)
# updating: content/json_data/pdf_resume_454.json (deflated 45%)
# updating: content/json_data/pdf_resume_380.json (stored 0%)
# updating: content/json_data/pdf_resume_856.json (deflated 43%)
# updating: content/json_data/pdf_resume_483.json (deflated 49%)
# updating: content/json_data/pdf_resume_767.json (deflated 48%)
# updating: content/json_data/pdf_resume_878.json (deflated 31%)
# updating: content/json_data/pdf_resume_289.json (deflated 52%)
# updating: content/json_data/pdf_resume_897.json (deflated 42%)
# updating: content/json_data/pdf_resume_102.json (deflated 38%)
# updating: content/json_data/pdf_resume_239.json (deflated 46%)
# updating: content/json_data/pdf_resume_550.json (deflated 49%)
# updating: content/json_data/pdf_resume_873.json (deflated 47%)
# updating: content/json_data/pdf_resume_222.json (deflated 31%)
# updating: content/json_data/pdf_resume_491.json (deflated 31%)
# updating: content/json_data/pdf_resume_241.json (deflated 37%)
# updating: content/json_data/pdf_resume_504.json (deflated 47%)
# updating: content/json_data/pdf_resume_857.json (stored 0%)
# updating: content/json_data/pdf_resume_370.json (deflated 43%)
# updating: content/json_data/pdf_resume_586.json (deflated 48%)
# updating: content/json_data/pdf_resume_925.json (deflated 46%)
# updating: content/json_data/pdf_resume_59.json (deflated 46%)
# updating: content/json_data/pdf_resume_990.json (deflated 45%)
# updating: content/json_data/pdf_resume_351.json (deflated 49%)
# updating: content/json_data/pdf_resume_732.json (deflated 52%)
# updating: content/json_data/pdf_resume_326.json (deflated 43%)
# updating: content/json_data/pdf_resume_90.json (deflated 45%)
# updating: content/json_data/pdf_resume_569.json (deflated 38%)
# updating: content/json_data/pdf_resume_112.json (deflated 32%)
# updating: content/json_data/pdf_resume_211.json (deflated 51%)
# updating: content/json_data/pdf_resume_67.json (deflated 45%)
# updating: content/json_data/pdf_resume_605.json (deflated 47%)
# updating: content/json_data/pdf_resume_347.json (deflated 49%)
# updating: content/json_data/pdf_resume_42.json (deflated 48%)
# updating: content/json_data/pdf_resume_75.json (stored 0%)
# updating: content/json_data/pdf_resume_428.json (deflated 46%)
# updating: content/json_data/pdf_resume_654.json (deflated 43%)
# updating: content/json_data/pdf_resume_668.json (deflated 50%)
# updating: content/json_data/pdf_resume_333.json (deflated 46%)
# updating: content/json_data/pdf_resume_242.json (deflated 51%)
# updating: content/json_data/pdf_resume_933.json (stored 0%)
# updating: content/json_data/pdf_resume_880.json (deflated 43%)
# updating: content/json_data/pdf_resume_467.json (deflated 44%)
# updating: content/json_data/pdf_resume_155.json (deflated 47%)
# updating: content/json_data/pdf_resume_846.json (deflated 45%)
# updating: content/json_data/pdf_resume_591.json (deflated 38%)
# updating: content/json_data/pdf_resume_899.json (deflated 53%)
# updating: content/json_data/pdf_resume_95.json (deflated 46%)
# updating: content/json_data/pdf_resume_422.json (deflated 49%)
# updating: content/json_data/pdf_resume_99.json (deflated 52%)
# updating: content/json_data/pdf_resume_529.json (deflated 50%)
# updating: content/json_data/pdf_resume_775.json (deflated 45%)
# updating: content/json_data/pdf_resume_144.json (deflated 49%)
# updating: content/json_data/pdf_resume_97.json (deflated 38%)
# updating: content/json_data/pdf_resume_849.json (deflated 36%)
# updating: content/json_data/pdf_resume_1016.json (deflated 18%)
# updating: content/json_data/pdf_resume_754.json (deflated 45%)
# updating: content/json_data/pdf_resume_889.json (deflated 44%)
# updating: content/json_data/pdf_resume_666.json (deflated 46%)
# updating: content/json_data/pdf_resume_741.json (deflated 39%)
# updating: content/json_data/pdf_resume_304.json (deflated 45%)
# updating: content/json_data/pdf_resume_640.json (deflated 43%)
# updating: content/json_data/pdf_resume_524.json (deflated 43%)
# updating: content/json_data/pdf_resume_145.json (deflated 40%)
# updating: content/json_data/pdf_resume_134.json (deflated 43%)
# updating: content/json_data/pdf_resume_609.json (deflated 49%)
# updating: content/json_data/pdf_resume_486.json (deflated 35%)
# updating: content/json_data/pdf_resume_607.json (deflated 49%)
# updating: content/json_data/pdf_resume_509.json (deflated 51%)
# updating: content/json_data/pdf_resume_980.json (deflated 47%)
# updating: content/json_data/pdf_resume_693.json (deflated 42%)
# updating: content/json_data/pdf_resume_599.json (deflated 43%)
# updating: content/json_data/pdf_resume_863.json (deflated 50%)
# updating: content/json_data/pdf_resume_70.json (stored 0%)
# updating: content/json_data/pdf_resume_235.json (deflated 46%)
# updating: content/json_data/pdf_resume_392.json (deflated 44%)
# updating: content/json_data/pdf_resume_827.json (deflated 44%)
# updating: content/json_data/pdf_resume_100.json (deflated 41%)
# updating: content/json_data/pdf_resume_44.json (stored 0%)
# updating: content/json_data/pdf_resume_974.json (stored 0%)
# updating: content/json_data/pdf_resume_398.json (deflated 53%)
# updating: content/json_data/pdf_resume_582.json (deflated 54%)
# updating: content/json_data/pdf_resume_229.json (stored 0%)
# updating: content/json_data/pdf_resume_774.json (deflated 53%)
# updating: content/json_data/pdf_resume_624.json (deflated 43%)
# updating: content/json_data/pdf_resume_515.json (deflated 54%)
# updating: content/json_data/pdf_resume_703.json (deflated 55%)
# updating: content/json_data/pdf_resume_517.json (deflated 37%)
# updating: content/json_data/pdf_resume_5.json (deflated 40%)
# updating: content/json_data/pdf_resume_858.json (deflated 46%)
# updating: content/json_data/pdf_resume_125.json (deflated 47%)
# updating: content/json_data/pdf_resume_555.json (deflated 45%)
# updating: content/json_data/pdf_resume_842.json (deflated 43%)
# updating: content/json_data/pdf_resume_116.json (deflated 39%)
# updating: content/json_data/pdf_resume_742.json (deflated 58%)
# updating: content/json_data/pdf_resume_126.json (deflated 42%)
# updating: content/json_data/pdf_resume_323.json (stored 0%)
# updating: content/json_data/pdf_resume_285.json (deflated 47%)
# updating: content/json_data/pdf_resume_438.json (deflated 50%)
# updating: content/json_data/pdf_resume_969.json (deflated 47%)
# updating: content/json_data/pdf_resume_66.json (deflated 20%)
# updating: content/json_data/pdf_resume_1008.json (stored 0%)
# updating: content/json_data/pdf_resume_337.json (deflated 49%)
# updating: content/json_data/pdf_resume_683.json (stored 0%)
# updating: content/json_data/pdf_resume_611.json (deflated 45%)
# updating: content/json_data/pdf_resume_926.json (deflated 49%)
# updating: content/json_data/pdf_resume_843.json (deflated 48%)
# updating: content/json_data/pdf_resume_1018.json (deflated 43%)
# updating: content/json_data/pdf_resume_993.json (deflated 47%)
# updating: content/json_data/pdf_resume_685.json (deflated 46%)
# updating: content/json_data/pdf_resume_238.json (stored 0%)
# updating: content/json_data/pdf_resume_295.json (deflated 42%)
# updating: content/json_data/pdf_resume_662.json (deflated 41%)
# updating: content/json_data/pdf_resume_1029.json (deflated 39%)
# updating: content/json_data/pdf_resume_699.json (deflated 49%)
# updating: content/json_data/pdf_resume_709.json (deflated 37%)
# updating: content/json_data/pdf_resume_68.json (deflated 48%)
# updating: content/json_data/pdf_resume_408.json (deflated 47%)
# updating: content/json_data/pdf_resume_552.json (deflated 46%)
# updating: content/json_data/pdf_resume_575.json (deflated 34%)
# updating: content/json_data/pdf_resume_807.json (deflated 40%)
# updating: content/json_data/pdf_resume_710.json (deflated 50%)
# updating: content/json_data/pdf_resume_396.json (deflated 53%)
# updating: content/json_data/pdf_resume_225.json (deflated 42%)
# updating: content/json_data/pdf_resume_615.json (deflated 41%)
# updating: content/json_data/pdf_resume_185.json (stored 0%)
# updating: content/json_data/pdf_resume_474.json (deflated 47%)
# updating: content/json_data/pdf_resume_228.json (deflated 50%)
# updating: content/json_data/pdf_resume_403.json (stored 0%)
# updating: content/json_data/pdf_resume_212.json (deflated 44%)
# updating: content/json_data/pdf_resume_1022.json (deflated 50%)
# updating: content/json_data/pdf_resume_885.json (deflated 51%)
# updating: content/json_data/pdf_resume_76.json (stored 0%)
# updating: content/json_data/pdf_resume_1026.json (deflated 52%)
# updating: content/json_data/pdf_resume_482.json (deflated 68%)
# updating: content/json_data/pdf_resume_312.json (deflated 49%)
# updating: content/json_data/pdf_resume_777.json (deflated 44%)
# updating: content/json_data/pdf_resume_630.json (deflated 44%)
# updating: content/json_data/pdf_resume_844.json (deflated 46%)
# updating: content/json_data/pdf_resume_255.json (deflated 55%)
# updating: content/json_data/pdf_resume_360.json (deflated 46%)
# updating: content/json_data/pdf_resume_537.json (deflated 47%)
# updating: content/json_data/pdf_resume_779.json (deflated 47%)
# updating: content/json_data/pdf_resume_560.json (stored 0%)
# updating: content/json_data/pdf_resume_769.json (deflated 47%)
# updating: content/json_data/pdf_resume_64.json (stored 0%)
# updating: content/json_data/pdf_resume_132.json (deflated 52%)
# updating: content/json_data/pdf_resume_214.json (stored 0%)
# updating: content/json_data/pdf_resume_576.json (deflated 47%)
# updating: content/json_data/pdf_resume_894.json (deflated 53%)
# updating: content/json_data/pdf_resume_216.json (deflated 51%)
# updating: content/json_data/pdf_resume_140.json (deflated 46%)
# updating: content/json_data/pdf_resume_1001.json (stored 0%)
# updating: content/json_data/pdf_resume_917.json (deflated 45%)
# updating: content/json_data/pdf_resume_448.json (deflated 45%)
# updating: content/json_data/pdf_resume_832.json (deflated 51%)
# updating: content/json_data/pdf_resume_649.json (stored 0%)
# updating: content/json_data/pdf_resume_277.json (deflated 57%)
# updating: content/json_data/pdf_resume_456.json (deflated 46%)
# updating: content/json_data/pdf_resume_943.json (stored 0%)
# updating: content/json_data/pdf_resume_350.json (deflated 50%)
# updating: content/json_data/pdf_resume_148.json (stored 0%)
# updating: content/json_data/pdf_resume_970.json (deflated 39%)
# updating: content/json_data/pdf_resume_399.json (deflated 36%)
# updating: content/json_data/pdf_resume_484.json (deflated 47%)
# updating: content/json_data/pdf_resume_339.json (deflated 46%)
# updating: content/json_data/pdf_resume_106.json (deflated 26%)
# updating: content/json_data/pdf_resume_171.json (deflated 49%)
# updating: content/json_data/pdf_resume_535.json (deflated 39%)
# updating: content/json_data/pdf_resume_890.json (deflated 42%)
# updating: content/json_data/pdf_resume_598.json (stored 0%)
# updating: content/json_data/pdf_resume_2.json (deflated 39%)
# updating: content/json_data/pdf_resume_629.json (deflated 30%)
# updating: content/json_data/pdf_resume_884.json (deflated 47%)
# updating: content/json_data/pdf_resume_589.json (deflated 46%)
# updating: content/json_data/pdf_resume_12.json (deflated 44%)
# updating: content/json_data/pdf_resume_644.json (deflated 44%)
# updating: content/json_data/pdf_resume_725.json (deflated 38%)
# updating: content/json_data/pdf_resume_738.json (deflated 41%)
# updating: content/json_data/pdf_resume_676.json (deflated 46%)
# updating: content/json_data/pdf_resume_601.json (deflated 45%)
# updating: content/json_data/pdf_resume_841.json (stored 0%)
# updating: content/json_data/pdf_resume_731.json (deflated 39%)
# updating: content/json_data/pdf_resume_286.json (stored 0%)
# updating: content/json_data/pdf_resume_313.json (deflated 48%)
# updating: content/json_data/pdf_resume_617.json (deflated 54%)
# updating: content/json_data/pdf_resume_463.json (deflated 45%)
# updating: content/json_data/pdf_resume_436.json (deflated 52%)
# updating: content/json_data/pdf_resume_135.json (deflated 46%)
# updating: content/json_data/pdf_resume_568.json (stored 0%)
# updating: content/json_data/pdf_resume_855.json (deflated 49%)
# updating: content/json_data/pdf_resume_989.json (deflated 44%)
# updating: content/json_data/pdf_resume_965.json (deflated 42%)
# updating: content/json_data/pdf_resume_918.json (stored 0%)
# updating: content/json_data/pdf_resume_421.json (deflated 53%)
# updating: content/json_data/pdf_resume_468.json (deflated 43%)
# updating: content/json_data/pdf_resume_922.json (deflated 41%)
# updating: content/json_data/pdf_resume_900.json (deflated 68%)
# updating: content/json_data/pdf_resume_658.json (deflated 44%)
# updating: content/json_data/pdf_resume_433.json (deflated 43%)
# updating: content/json_data/pdf_resume_22.json (deflated 49%)
# updating: content/json_data/pdf_resume_661.json (deflated 52%)
# updating: content/json_data/pdf_resume_1027.json (deflated 49%)
# updating: content/json_data/pdf_resume_618.json (deflated 48%)
# updating: content/json_data/pdf_resume_520.json (deflated 54%)
# updating: content/json_data/pdf_resume_526.json (deflated 39%)
# updating: content/json_data/pdf_resume_888.json (stored 0%)
# updating: content/json_data/pdf_resume_446.json (deflated 54%)
# updating: content/json_data/pdf_resume_325.json (deflated 54%)
# updating: content/json_data/pdf_resume_542.json (deflated 37%)
# updating: content/json_data/pdf_resume_919.json (deflated 47%)
# updating: content/json_data/pdf_resume_24.json (deflated 40%)
# updating: content/json_data/pdf_resume_921.json (deflated 41%)
# updating: content/json_data/pdf_resume_532.json (deflated 63%)
# updating: content/json_data/pdf_resume_941.json (deflated 51%)
# updating: content/json_data/pdf_resume_923.json (deflated 49%)
# updating: content/json_data/pdf_resume_810.json (deflated 50%)
# updating: content/json_data/pdf_resume_610.json (deflated 44%)
# updating: content/json_data/pdf_resume_249.json (deflated 49%)
# updating: content/json_data/pdf_resume_481.json (deflated 49%)
# updating: content/json_data/pdf_resume_359.json (deflated 46%)
# updating: content/json_data/pdf_resume_154.json (deflated 42%)
# updating: content/json_data/pdf_resume_260.json (deflated 53%)
# updating: content/json_data/pdf_resume_443.json (deflated 48%)
# updating: content/json_data/pdf_resume_292.json (stored 0%)
# updating: content/json_data/pdf_resume_867.json (deflated 25%)
# updating: content/json_data/pdf_resume_587.json (deflated 59%)
# updating: content/json_data/pdf_resume_237.json (deflated 45%)
# updating: content/json_data/pdf_resume_182.json (deflated 48%)
# updating: content/json_data/pdf_resume_720.json (deflated 45%)
# updating: content/json_data/pdf_resume_580.json (deflated 47%)
# updating: content/json_data/pdf_resume_25.json (deflated 35%)
# updating: content/json_data/pdf_resume_866.json (deflated 45%)
# updating: content/json_data/pdf_resume_600.json (deflated 45%)
# updating: content/json_data/pdf_resume_764.json (deflated 42%)
# updating: content/json_data/pdf_resume_930.json (deflated 47%)
# updating: content/json_data/pdf_resume_203.json (deflated 20%)
# updating: content/json_data/pdf_resume_816.json (stored 0%)
# updating: content/json_data/pdf_resume_136.json (deflated 51%)
# updating: content/json_data/pdf_resume_345.json (deflated 44%)
# updating: content/json_data/pdf_resume_77.json (deflated 48%)
# updating: content/json_data/pdf_resume_311.json (deflated 38%)
# updating: content/json_data/pdf_resume_623.json (deflated 41%)
# updating: content/json_data/pdf_resume_968.json (deflated 44%)
# updating: content/json_data/pdf_resume_469.json (deflated 50%)
# updating: content/json_data/pdf_resume_664.json (deflated 43%)
# updating: content/json_data/pdf_resume_190.json (deflated 44%)
# updating: content/json_data/pdf_resume_113.json (deflated 51%)
# updating: content/json_data/pdf_resume_320.json (deflated 42%)
# updating: content/json_data/pdf_resume_1021.json (deflated 47%)
# updating: content/json_data/pdf_resume_480.json (deflated 37%)
# updating: content/json_data/pdf_resume_303.json (stored 0%)
# updating: content/json_data/pdf_resume_748.json (deflated 43%)
# updating: content/json_data/pdf_resume_393.json (deflated 39%)
# updating: content/json_data/pdf_resume_896.json (deflated 50%)
# updating: content/json_data/pdf_resume_103.json (deflated 48%)
# updating: content/json_data/pdf_resume_272.json (deflated 52%)
# updating: content/json_data/pdf_resume_391.json (deflated 39%)
# updating: content/json_data/pdf_resume_628.json (deflated 51%)

# %%
import os
if os.path.isdir('/content/type3/.ipynb_checkpoints'):
  os.removedirs('/content/type3/.ipynb_checkpoints')
